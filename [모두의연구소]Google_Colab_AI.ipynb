# %% [markdown]
# <a href="https://colab.research.google.com/github/Um-king/orm/blob/main/%5B%EB%AA%A8%EB%91%90%EC%9D%98%EC%97%B0%EA%B5%AC%EC%86%8C%5DGoogle_Colab_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 구글 코랩 AI
#
# 오늘은 구글 코랩 AI 사용법에 대해서 알아볼 거에요
#
# * colab 내에서 언제든 활용 가능
#
#
# \#: 대제목
#
# \*: 순서가 없는 구분자
#
#
#
# ![2023-12-28 17 23 31.png](data:image/png;base64,...)

# %%
# Colab AI를 사용한 빙고게임 코드 (5*5)

import random

# Define the board size
board_size = 5

# Create a 5x5 board
board = [[' ' for _ in range(board_size)] for _ in range(board_size)]

# Fill the board with numbers
for i in range(board_size):
  for j in range(board_size):
    board[i][j] = random.randint(1, 25)

# Print the board
for row in board:
  print(' '.join(map(str, row)))

# Get the user's guess
guess = int(input('Enter your guess: '))

# Check if the guess is on the board
if guess in board:
  # Print a message saying the guess is correct
  print('Your guess is correct!')
else:
  # Print a message saying the guess is incorrect
  print('Your guess is incorrect.')
# Out:
# 24 19 18 19 25
# 23 4 24 21 24
# 21 16 12 11 2
# 2 15 10 14 24
# 8 8 16 15 7
# Enter your guess: 8
# Your guess is incorrect.

# %%
# prompt: 샘플 데이터 프레임 하나 생성해줘.

import pandas as pd
df = pd.DataFrame({
  'name': ['Alice', 'Bob', 'Carol', 'Dave', 'Eve'],
  'age': [20, 25, 30, 35, 40]
})

# %%
df
# Out:
#     name  age
# 0  Alice   20
# 1    Bob   25
# 2  Carol   30
# 3   Dave   35
# 4    Eve   40

# %%
# prompt: df DataFrame 사용: 해당 데이터셋으로 막대그래프를 그리고 싶어.

import matplotlib.pyplot as plt
df.plot.bar(x='name', y='age')
plt.show()
